# %% [markdown]
# # Quick Start: Scalar Transport
#
# This notebook demonstrates a minimal transient scalar transport setup: a Gaussian pulse advected
# through a 2D channel using HDG with BDF2 time integration.

# %%
import numpy as np
import ngsolve as ngs
from dream.mesh import get_rectangular_mesh
from dream.scalar_transport import ScalarTransportSolver, transportfields
from dream.scalar_transport.config import FarField, Initial

# %%
# Build a simple channel mesh
nx = np.linspace(0.0, 4.0, 41)
ny = np.linspace(-0.5, 0.5, 11)
mesh = get_rectangular_mesh(
    [("channel", (nx, ny))],
    [("inflow",  (np.array([0.0]), ny)),
     ("outflow", (np.array([4.0]), ny)),
     ("wall",    (nx, np.array([-0.5]))),
     ("wall",    (nx, np.array([ 0.5])))],
)

# %%
solver = ScalarTransportSolver(mesh)

# Physical parameters
solver.convection_velocity   = ngs.CF((1.0, 0.0))
solver.diffusion_coefficient = 1e-3

# Discretisation
solver.fem            = 'hdg'
solver.fem.order      = 3
solver.riemann_solver = 'lax_friedrich'

# Time integration
solver.time                = 'transient'
solver.fem.scheme          = 'bdf2'
solver.time.timer.interval = (0.0, 2.0)
solver.time.timer.step     = 5e-3

# Boundary and initial conditions
Uinf = transportfields(u=0.0)
U0   = transportfields(u=ngs.exp(-50 * (ngs.y**2)))

solver.bcs['inflow']  = FarField(fields=U0)
solver.bcs['outflow'] = FarField(fields=Uinf)
solver.dcs['channel'] = Initial(fields=transportfields(u=0.0))

with ngs.TaskManager():
    # Sets up finite element spaces, assembles bilinear forms and applies boundary conditions
    solver.initialize()
    # Runs the time-stepping loop defined by solver.time
    solver.solve()
# Out:
# dream.time      (INFO) | transient | hdg bdf2 | t: 5.000000e-03
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.000000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.500000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.000000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.500000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.000000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.500000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 4.000000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 4.500000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 5.000000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 5.500000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 6.000000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 6.500000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 7.000000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 7.500000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 8.000000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 8.500000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 9.000000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 9.500000e-02
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.000000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.050000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.100000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.150000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.200000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.250000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.300000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.350000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.400000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.450000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.500000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.550000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.600000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.650000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.700000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.750000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.800000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.850000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.900000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 1.950000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.000000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.050000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.100000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.150000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.200000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.250000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.300000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.350000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.400000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.450000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.500000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.550000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.600000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.650000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.700000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.750000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.800000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.850000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.900000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 2.950000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.000000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.050000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.100000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.150000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.200000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.250000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.300000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.350000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.400000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.450000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.500000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.550000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: 3.600000e-01
# dream.time      (INFO) | transient | hdg bdf2 | t: