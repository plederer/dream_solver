# %% [markdown]
# ## Tutorial: Scalar wave equation in 1D
#
# This example describes a wave equation moving along a flow with a constant velocity. The (non-dimensional) equation we are solving is a linear convection equation in 1D
# $$
# \partial_t u + b \partial_x u = 0, \qquad \forall\, x \in \Omega = [-2,+2], \quad t \in [0, 12],
# $$
# where the wind velocity is $b = 1.0$.
#
# The exact solution to this PDE, known as d'Alembert's solution, is a simple shift of the initial condition along the velocity. In other words, for an initial solution $u(x,t_0) = f(x)$, the exact solution at any given moment is $u(x,t) = f(x - bt)$. We choose a Gaussian profile to express the solution, with the following form
# $$
# u(x,t) = \frac{1}{\sigma\sqrt{\pi}} e^{-r^2/(2 \sigma^2)},
# $$
# where the standard deviation is $\sigma = 0.15$ and the (time-dependent) radial distance is $r^2 = (x(t) - x_0)^2$, with $x(t) = x - b t$ denoting the moving frame of reference and $x_0 = 0$ is the initial pulse location at $t = t_0$. Of course, the initial solution is simply $u(x, 0)$.

# %%
# Import preliminary modules.
from dream import *
from dream.scalar_transport import Initial, transportfields, ScalarTransportSolver
from ngsolve import *
from ngsolve.meshes import Make1DMesh
from matplotlib import pyplot as plt

# %%
# Generate the grid.
ne =  20
x0 = -2.0 
x1 =  2.0
lx =  x1 - x0

# Generate a simple grid.
mesh = Make1DMesh(ne, periodic=True, mapping=lambda x: lx*x + x0 )

# Message output detail from netgen.
ngs.ngsglobals.msg_level = 0 
ngs.SetNumThreads(4)

# %%
# Define the analytic solution.
def get_analytic_solution(t, v): 

    # Initial pulse location.
    x0 = 0.0 
    # Variance.
    s2 = 0.0225
    
    # Pulse center.
    xt = ngs.x - v*t 
    # Number of cycle throughout the simulation.
    n_cycle = 4 
    
    # Main function.
    f = ngs.exp( -(xt-x0)**2/(2.0*s2) )/( sqrt(s2*ngs.pi) )
    
    # Cycles of this function (lagging by lx, assuming v>0).
    for i in range(1,n_cycle):
        x0t = x0 - i*lx
        f += ngs.exp( -(xt - x0t)**2/(2.0*s2) )/( sqrt(s2*ngs.pi) )
    return f

# %%
# Solver configuration: pure convection equation.
cfg = ScalarTransportSolver(mesh)

cfg.convection_velocity = (1.0,)
cfg.is_inviscid = True

cfg.riemann_solver = "lax_friedrich"
cfg.fem = "dg" # NOTE, by default, DG is used.
cfg.fem.static_condensation = False  # NOTE, by default, condensation is turned off.
cfg.fem.order = 0

cfg.time = "transient"
cfg.fem.scheme = "implicit_euler"
cfg.time.timer.interval = (0.0, 12.0)
cfg.time.timer.step = 0.01

U0 = transportfields()
U0.u = get_analytic_solution(cfg.time.timer.interval[0], cfg.convection_velocity[0])

cfg.bcs['left|right'] = "periodic"
cfg.dcs['dom'] = Initial(fields=U0)

# %%
# Decorator for the actual simulation.
import numpy as np  

# Extract time configuration.
t0, tf = cfg.time.timer.interval
dt = cfg.time.timer.step.Get()
nt = int(round((tf - t0) / dt))

# Define a decorator for the wave equation routine.
def wave1d_routine(label):
    def decorator(func):
        def wrapper(*args, **kwargs):

            # By default, assume this is a DG formulation.
            cfg.fem.static_condensation = False

            # Insert options here.
            func(*args, **kwargs)
            cfg.fem.order = 5

            # In case an HDG formulation is specified, use static condensation.
            if cfg.fem.name == "hdg":
                cfg.fem.static_condensation = True
            
            # Allocate the necessary data.
            cfg.initialize()

            # Get a reference to the numerical solution and the analytic solution.
            uh = cfg.fem.get_fields("u").u
            ue_func = get_analytic_solution(cfg.time.timer.t, cfg.convection_velocity[0])

            # Generate a local mesh here, since it depends on the polynomial order.
            xcoor = np.linspace(x0, x1, ne * cfg.fem.order, dtype=float)

            # Integration order (for post-processing).
            qorder = 10

            # Data for book-keeping information.
            data = np.zeros((nt, 2), dtype=float)


            # Time integration loop (actual simulation).
            for i, t in enumerate(cfg.time.start_solution_routine(True)):
                
                # Compute the L2-norm of the error.
                err = np.sqrt(ngs.Integrate((ue_func - uh) ** 2, mesh, order=qorder))

                # Store data: time and error metrics.
                data[i] = [cfg.time.timer.t.Get(), err]

            # Evaluate the solution at final time.
            u_final = uh(mesh(xcoor))
            return data, xcoor, u_final
        wrapper.label = label
        return wrapper
    return decorator

# %%
# Specialized simulation routines.
@wave1d_routine("implicit_euler(hdg)")
def implicit_euler_hdg():
    cfg.fem = "hdg"
    cfg.fem.scheme = "implicit_euler"
    
@wave1d_routine("implicit_euler(dg)")
def implicit_euler_dg():
    cfg.fem = "dg"
    cfg.fem.scheme = "implicit_euler"

@wave1d_routine("bdf2(hdg)")
def bdf2_hdg():
    cfg.fem = "hdg"
    cfg.fem.scheme = "bdf2"
@wave1d_routine("bdf2(dg)")
def bdf2_dg():
    cfg.fem = "dg"
    cfg.fem.scheme = "bdf2"

@wave1d_routine("sdirk22(hdg)")
def sdirk22_hdg():
    cfg.fem = "hdg"
    cfg.fem.scheme = "sdirk22"
@wave1d_routine("sdirk22(dg)")
def sdirk22_dg():
    cfg.fem = "dg"
    cfg.fem.scheme = "sdirk22"

@wave1d_routine("sdirk33(hdg)")
def sdirk33_hdg():
    cfg.fem = "hdg"
    cfg.fem.scheme = "sdirk33"
@wave1d_routine("sdirk33(dg)")
def sdirk33_dg():
    cfg.fem = "dg"
    cfg.fem.scheme = "sdirk33"

@wave1d_routine("imex_rk_ars443(dg)")
def imex_rk_ars443_dg():
    cfg.fem = "dg"
    cfg.fem.scheme = "imex_rk_ars443"

@wave1d_routine("ssprk3(dg)")
def ssprk3_dg():
    cfg.fem = "dg"
    cfg.fem.scheme = "ssprk3"

@wave1d_routine("crk4(dg)")
def crk4_dg():
    cfg.fem = "dg"
    cfg.fem.scheme = "crk4"

@wave1d_routine("explicit_euler(dg)")
def explicit_euler_dg():
    cfg.fem = "dg"
    cfg.fem.scheme = "explicit_euler"

# %%
# Figure style and properties.

# Assign colors to base method names
method_colors = {
    "implicit_euler": "tab:red",
    "bdf2": "tab:blue",
    "sdirk22": "tab:green",
    "sdirk33": "tab:purple"
}

# Helper function that sets up a generic figure.
def setup_fig(xlabel, ylabel, title):
    fig, ax = plt.subplots(figsize=(15, 6))
    ax.tick_params(axis='both', labelsize=16)
    ax.set_xlabel(xlabel, fontsize=14)
    ax.set_ylabel(ylabel, fontsize=16)
    ax.set_title(title, fontsize=16)
    ax.grid(True)
    return fig,ax

# Helper function that specifies the plot style properties.
def get_plot_style(label, method_colors):
    if label.endswith("(hdg)"):
        base_name = label.replace("(hdg)", "").strip()
        linestyle = "-"
        marker = 'o'
    elif label.endswith("(dg)"):
        base_name = label.replace("(dg)", "").strip()
        linestyle = "--"
        marker = '^'
    else:
        base_name = label.strip()
        linestyle = ":"
        marker = '.'

    color = method_colors.get(base_name, "black")

    return {
        "label": label,
        "linestyle": linestyle,
        "marker": marker,
        "markersize": 8,
        "markevery": 50,
        "color": color
    }

# %%
# Run simulation(s).
routines = [implicit_euler_hdg, implicit_euler_dg,
                      bdf2_hdg,           bdf2_dg,
                   sdirk22_hdg,        sdirk22_dg,
                   sdirk33_hdg,        sdirk33_dg]

plt.ioff()

# Figure 1: logaraithmic plot of the relative error in the L2-norm.
fig1, ax1 = setup_fig("Time", r"L2-norm[Ue - Uh]", "Time Evolution of Relative L2-norm[Ue - Uh]")

# Figure 2: instantaneous solution at the final time step.
fig2, ax2 = setup_fig("x", "u(x, t_final)", f"Final Solution at t = {tf}")

# Run each simulation.
for routine in routines:
    print(f"Running {routine.label}...")
    data, xcoor, usol = routine()
    style = get_plot_style(routine.label, method_colors)

    ax1.semilogy(data[:, 0], data[:, 1], **style)
    ax2.plot(xcoor, usol, **style)

# Plot analytic solution at the final step.
ue_final = get_analytic_solution(t0, cfg.convection_velocity[0])
ax2.plot(xcoor, ue_final(mesh(xcoor)), 'k-')

# Final touches.
ax1.legend(loc="lower right", frameon=False)
ax2.legend(loc="upper right", frameon=False)
ax1.set_xlim(t0, tf)
ax2.set_xlim(x0, x1)
fig1.tight_layout()
fig2.tight_layout()

# Let's see our masterpiece..
plt.show()
# Out:
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.000000e-02
# dream.time      (INFO) | Solved interval 0.000000e+00 to 1.000000e-02
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.000000e-02
# dream.time      (INFO) | Solved interval 1.000000e-02 to 2.000000e-02
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.000000e-02
# dream.time      (INFO) | Solved interval 2.000000e-02 to 3.000000e-02
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.000000e-02
# dream.time      (INFO) | Solved interval 3.000000e-02 to 4.000000e-02
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.000000e-02
# dream.time      (INFO) | Solved interval 4.000000e-02 to 5.000000e-02
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.000000e-02
# dream.time      (INFO) | Solved interval 5.000000e-02 to 6.000000e-02
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.000000e-02
# dream.time      (INFO) | Solved interval 6.000000e-02 to 7.000000e-02
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.000000e-02
# dream.time      (INFO) | Solved interval 7.000000e-02 to 8.000000e-02
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.000000e-02
# dream.time      (INFO) | Solved interval 8.000000e-02 to 9.000000e-02
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.000000e-01
# dream.time      (INFO) | Solved interval 9.000000e-02 to 1.000000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.100000e-01
# dream.time      (INFO) | Solved interval 1.000000e-01 to 1.100000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.200000e-01
# dream.time      (INFO) | Solved interval 1.100000e-01 to 1.200000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.300000e-01
# dream.time      (INFO) | Solved interval 1.200000e-01 to 1.300000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.400000e-01
# dream.time      (INFO) | Solved interval 1.300000e-01 to 1.400000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.500000e-01
# dream.time      (INFO) | Solved interval 1.400000e-01 to 1.500000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.600000e-01
# dream.time      (INFO) | Solved interval 1.500000e-01 to 1.600000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.700000e-01
# dream.time      (INFO) | Solved interval 1.600000e-01 to 1.700000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.800000e-01
# dream.time      (INFO) | Solved interval 1.700000e-01 to 1.800000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.900000e-01
# dream.time      (INFO) | Solved interval 1.800000e-01 to 1.900000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.000000e-01
# dream.time      (INFO) | Solved interval 1.900000e-01 to 2.000000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.100000e-01
# dream.time      (INFO) | Solved interval 2.000000e-01 to 2.100000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.200000e-01
# dream.time      (INFO) | Solved interval 2.100000e-01 to 2.200000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.300000e-01
# dream.time      (INFO) | Solved interval 2.200000e-01 to 2.300000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.400000e-01
# dream.time      (INFO) | Solved interval 2.300000e-01 to 2.400000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.500000e-01
# dream.time      (INFO) | Solved interval 2.400000e-01 to 2.500000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.600000e-01
# dream.time      (INFO) | Solved interval 2.500000e-01 to 2.600000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.700000e-01
# dream.time      (INFO) | Solved interval 2.600000e-01 to 2.700000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.800000e-01
# dream.time      (INFO) | Solved interval 2.700000e-01 to 2.800000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.900000e-01
# dream.time      (INFO) | Solved interval 2.800000e-01 to 2.900000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.000000e-01
# dream.time      (INFO) | Solved interval 2.900000e-01 to 3.000000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.100000e-01
# dream.time      (INFO) | Solved interval 3.000000e-01 to 3.100000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.200000e-01
# dream.time      (INFO) | Solved interval 3.100000e-01 to 3.200000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.300000e-01
# dream.time      (INFO) | Solved interval 3.200000e-01 to 3.300000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.400000e-01
# dream.time      (INFO) | Solved interval 3.300000e-01 to 3.400000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.500000e-01
# dream.time      (INFO) | Solved interval 3.400000e-01 to 3.500000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.600000e-01
# dream.time      (INFO) | Solved interval 3.500000e-01 to 3.600000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.700000e-01
# dream.time      (INFO) | Solved interval 3.600000e-01 to 3.700000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.800000e-01
# dream.time      (INFO) | Solved interval 3.700000e-01 to 3.800000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.900000e-01
# dream.time      (INFO) | Solved interval 3.800000e-01 to 3.900000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.000000e-01
# dream.time      (INFO) | Solved interval 3.900000e-01 to 4.000000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.100000e-01
# dream.time      (INFO) | Solved interval 4.000000e-01 to 4.100000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.200000e-01
# dream.time      (INFO) | Solved interval 4.100000e-01 to 4.200000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.300000e-01
# dream.time      (INFO) | Solved interval 4.200000e-01 to 4.300000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.400000e-01
# dream.time      (INFO) | Solved interval 4.300000e-01 to 4.400000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.500000e-01
# dream.time      (INFO) | Solved interval 4.400000e-01 to 4.500000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.600000e-01
# dream.time      (INFO) | Solved interval 4.500000e-01 to 4.600000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.700000e-01
# dream.time      (INFO) | Solved interval 4.600000e-01 to 4.700000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.800000e-01
# dream.time      (INFO) | Solved interval 4.700000e-01 to 4.800000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 4.900000e-01
# dream.time      (INFO) | Solved interval 4.800000e-01 to 4.900000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.000000e-01
# dream.time      (INFO) | Solved interval 4.900000e-01 to 5.000000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.100000e-01
# dream.time      (INFO) | Solved interval 5.000000e-01 to 5.100000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.200000e-01
# dream.time      (INFO) | Solved interval 5.100000e-01 to 5.200000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.300000e-01
# dream.time      (INFO) | Solved interval 5.200000e-01 to 5.300000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.400000e-01
# dream.time      (INFO) | Solved interval 5.300000e-01 to 5.400000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.500000e-01
# dream.time      (INFO) | Solved interval 5.400000e-01 to 5.500000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.600000e-01
# dream.time      (INFO) | Solved interval 5.500000e-01 to 5.600000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.700000e-01
# dream.time      (INFO) | Solved interval 5.600000e-01 to 5.700000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.800000e-01
# dream.time      (INFO) | Solved interval 5.700000e-01 to 5.800000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 5.900000e-01
# dream.time      (INFO) | Solved interval 5.800000e-01 to 5.900000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.000000e-01
# dream.time      (INFO) | Solved interval 5.900000e-01 to 6.000000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.100000e-01
# dream.time      (INFO) | Solved interval 6.000000e-01 to 6.100000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.200000e-01
# dream.time      (INFO) | Solved interval 6.100000e-01 to 6.200000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.300000e-01
# dream.time      (INFO) | Solved interval 6.200000e-01 to 6.300000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.400000e-01
# dream.time      (INFO) | Solved interval 6.300000e-01 to 6.400000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.500000e-01
# dream.time      (INFO) | Solved interval 6.400000e-01 to 6.500000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.600000e-01
# dream.time      (INFO) | Solved interval 6.500000e-01 to 6.600000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.700000e-01
# dream.time      (INFO) | Solved interval 6.600000e-01 to 6.700000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.800000e-01
# dream.time      (INFO) | Solved interval 6.700000e-01 to 6.800000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 6.900000e-01
# dream.time      (INFO) | Solved interval 6.800000e-01 to 6.900000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.000000e-01
# dream.time      (INFO) | Solved interval 6.900000e-01 to 7.000000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.100000e-01
# dream.time      (INFO) | Solved interval 7.000000e-01 to 7.100000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.200000e-01
# dream.time      (INFO) | Solved interval 7.100000e-01 to 7.200000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.300000e-01
# dream.time      (INFO) | Solved interval 7.200000e-01 to 7.300000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.400000e-01
# dream.time      (INFO) | Solved interval 7.300000e-01 to 7.400000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.500000e-01
# dream.time      (INFO) | Solved interval 7.400000e-01 to 7.500000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.600000e-01
# dream.time      (INFO) | Solved interval 7.500000e-01 to 7.600000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.700000e-01
# dream.time      (INFO) | Solved interval 7.600000e-01 to 7.700000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.800000e-01
# dream.time      (INFO) | Solved interval 7.700000e-01 to 7.800000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 7.900000e-01
# dream.time      (INFO) | Solved interval 7.800000e-01 to 7.900000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.000000e-01
# dream.time      (INFO) | Solved interval 7.900000e-01 to 8.000000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.100000e-01
# dream.time      (INFO) | Solved interval 8.000000e-01 to 8.100000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.200000e-01
# dream.time      (INFO) | Solved interval 8.100000e-01 to 8.200000e-01
# Running implicit_euler(hdg)...
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.300000e-01
# dream.time      (INFO) | Solved interval 8.200000e-01 to 8.300000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.400000e-01
# dream.time      (INFO) | Solved interval 8.300000e-01 to 8.400000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.500000e-01
# dream.time      (INFO) | Solved interval 8.400000e-01 to 8.500000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.600000e-01
# dream.time      (INFO) | Solved interval 8.500000e-01 to 8.600000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.700000e-01
# dream.time      (INFO) | Solved interval 8.600000e-01 to 8.700000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.800000e-01
# dream.time      (INFO) | Solved interval 8.700000e-01 to 8.800000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 8.900000e-01
# dream.time      (INFO) | Solved interval 8.800000e-01 to 8.900000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.000000e-01
# dream.time      (INFO) | Solved interval 8.900000e-01 to 9.000000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.100000e-01
# dream.time      (INFO) | Solved interval 9.000000e-01 to 9.100000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.200000e-01
# dream.time      (INFO) | Solved interval 9.100000e-01 to 9.200000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.300000e-01
# dream.time      (INFO) | Solved interval 9.200000e-01 to 9.300000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.400000e-01
# dream.time      (INFO) | Solved interval 9.300000e-01 to 9.400000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.500000e-01
# dream.time      (INFO) | Solved interval 9.400000e-01 to 9.500000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.600000e-01
# dream.time      (INFO) | Solved interval 9.500000e-01 to 9.600000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.700000e-01
# dream.time      (INFO) | Solved interval 9.600000e-01 to 9.700000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.800000e-01
# dream.time      (INFO) | Solved interval 9.700000e-01 to 9.800000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 9.900000e-01
# dream.time      (INFO) | Solved interval 9.800000e-01 to 9.900000e-01
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.000000e+00
# dream.time      (INFO) | Solved interval 9.900000e-01 to 1.000000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.010000e+00
# dream.time      (INFO) | Solved interval 1.000000e+00 to 1.010000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.020000e+00
# dream.time      (INFO) | Solved interval 1.010000e+00 to 1.020000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.030000e+00
# dream.time      (INFO) | Solved interval 1.020000e+00 to 1.030000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.040000e+00
# dream.time      (INFO) | Solved interval 1.030000e+00 to 1.040000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.050000e+00
# dream.time      (INFO) | Solved interval 1.040000e+00 to 1.050000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.060000e+00
# dream.time      (INFO) | Solved interval 1.050000e+00 to 1.060000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.070000e+00
# dream.time      (INFO) | Solved interval 1.060000e+00 to 1.070000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.080000e+00
# dream.time      (INFO) | Solved interval 1.070000e+00 to 1.080000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.090000e+00
# dream.time      (INFO) | Solved interval 1.080000e+00 to 1.090000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.100000e+00
# dream.time      (INFO) | Solved interval 1.090000e+00 to 1.100000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.110000e+00
# dream.time      (INFO) | Solved interval 1.100000e+00 to 1.110000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.120000e+00
# dream.time      (INFO) | Solved interval 1.110000e+00 to 1.120000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.130000e+00
# dream.time      (INFO) | Solved interval 1.120000e+00 to 1.130000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.140000e+00
# dream.time      (INFO) | Solved interval 1.130000e+00 to 1.140000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.150000e+00
# dream.time      (INFO) | Solved interval 1.140000e+00 to 1.150000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.160000e+00
# dream.time      (INFO) | Solved interval 1.150000e+00 to 1.160000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.170000e+00
# dream.time      (INFO) | Solved interval 1.160000e+00 to 1.170000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.180000e+00
# dream.time      (INFO) | Solved interval 1.170000e+00 to 1.180000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.190000e+00
# dream.time      (INFO) | Solved interval 1.180000e+00 to 1.190000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.200000e+00
# dream.time      (INFO) | Solved interval 1.190000e+00 to 1.200000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.210000e+00
# dream.time      (INFO) | Solved interval 1.200000e+00 to 1.210000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.220000e+00
# dream.time      (INFO) | Solved interval 1.210000e+00 to 1.220000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.230000e+00
# dream.time      (INFO) | Solved interval 1.220000e+00 to 1.230000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.240000e+00
# dream.time      (INFO) | Solved interval 1.230000e+00 to 1.240000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.250000e+00
# dream.time      (INFO) | Solved interval 1.240000e+00 to 1.250000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.260000e+00
# dream.time      (INFO) | Solved interval 1.250000e+00 to 1.260000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.270000e+00
# dream.time      (INFO) | Solved interval 1.260000e+00 to 1.270000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.280000e+00
# dream.time      (INFO) | Solved interval 1.270000e+00 to 1.280000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.290000e+00
# dream.time      (INFO) | Solved interval 1.280000e+00 to 1.290000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.300000e+00
# dream.time      (INFO) | Solved interval 1.290000e+00 to 1.300000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.310000e+00
# dream.time      (INFO) | Solved interval 1.300000e+00 to 1.310000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.320000e+00
# dream.time      (INFO) | Solved interval 1.310000e+00 to 1.320000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.330000e+00
# dream.time      (INFO) | Solved interval 1.320000e+00 to 1.330000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.340000e+00
# dream.time      (INFO) | Solved interval 1.330000e+00 to 1.340000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.350000e+00
# dream.time      (INFO) | Solved interval 1.340000e+00 to 1.350000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.360000e+00
# dream.time      (INFO) | Solved interval 1.350000e+00 to 1.360000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.370000e+00
# dream.time      (INFO) | Solved interval 1.360000e+00 to 1.370000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.380000e+00
# dream.time      (INFO) | Solved interval 1.370000e+00 to 1.380000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.390000e+00
# dream.time      (INFO) | Solved interval 1.380000e+00 to 1.390000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.400000e+00
# dream.time      (INFO) | Solved interval 1.390000e+00 to 1.400000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.410000e+00
# dream.time      (INFO) | Solved interval 1.400000e+00 to 1.410000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.420000e+00
# dream.time      (INFO) | Solved interval 1.410000e+00 to 1.420000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.430000e+00
# dream.time      (INFO) | Solved interval 1.420000e+00 to 1.430000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.440000e+00
# dream.time      (INFO) | Solved interval 1.430000e+00 to 1.440000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.450000e+00
# dream.time      (INFO) | Solved interval 1.440000e+00 to 1.450000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.460000e+00
# dream.time      (INFO) | Solved interval 1.450000e+00 to 1.460000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.470000e+00
# dream.time      (INFO) | Solved interval 1.460000e+00 to 1.470000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.480000e+00
# dream.time      (INFO) | Solved interval 1.470000e+00 to 1.480000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.490000e+00
# dream.time      (INFO) | Solved interval 1.480000e+00 to 1.490000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.500000e+00
# dream.time      (INFO) | Solved interval 1.490000e+00 to 1.500000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.510000e+00
# dream.time      (INFO) | Solved interval 1.500000e+00 to 1.510000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.520000e+00
# dream.time      (INFO) | Solved interval 1.510000e+00 to 1.520000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.530000e+00
# dream.time      (INFO) | Solved interval 1.520000e+00 to 1.530000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.540000e+00
# dream.time      (INFO) | Solved interval 1.530000e+00 to 1.540000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.550000e+00
# dream.time      (INFO) | Solved interval 1.540000e+00 to 1.550000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.560000e+00
# dream.time      (INFO) | Solved interval 1.550000e+00 to 1.560000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.570000e+00
# dream.time      (INFO) | Solved interval 1.560000e+00 to 1.570000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.580000e+00
# dream.time      (INFO) | Solved interval 1.570000e+00 to 1.580000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.590000e+00
# dream.time      (INFO) | Solved interval 1.580000e+00 to 1.590000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.600000e+00
# dream.time      (INFO) | Solved interval 1.590000e+00 to 1.600000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.610000e+00
# dream.time      (INFO) | Solved interval 1.600000e+00 to 1.610000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.620000e+00
# dream.time      (INFO) | Solved interval 1.610000e+00 to 1.620000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.630000e+00
# dream.time      (INFO) | Solved interval 1.620000e+00 to 1.630000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.640000e+00
# dream.time      (INFO) | Solved interval 1.630000e+00 to 1.640000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.650000e+00
# dream.time      (INFO) | Solved interval 1.640000e+00 to 1.650000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.660000e+00
# dream.time      (INFO) | Solved interval 1.650000e+00 to 1.660000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.670000e+00
# dream.time      (INFO) | Solved interval 1.660000e+00 to 1.670000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.680000e+00
# dream.time      (INFO) | Solved interval 1.670000e+00 to 1.680000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.690000e+00
# dream.time      (INFO) | Solved interval 1.680000e+00 to 1.690000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.700000e+00
# dream.time      (INFO) | Solved interval 1.690000e+00 to 1.700000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.710000e+00
# dream.time      (INFO) | Solved interval 1.700000e+00 to 1.710000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.720000e+00
# dream.time      (INFO) | Solved interval 1.710000e+00 to 1.720000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.730000e+00
# dream.time      (INFO) | Solved interval 1.720000e+00 to 1.730000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.740000e+00
# dream.time      (INFO) | Solved interval 1.730000e+00 to 1.740000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.750000e+00
# dream.time      (INFO) | Solved interval 1.740000e+00 to 1.750000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.760000e+00
# dream.time      (INFO) | Solved interval 1.750000e+00 to 1.760000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.770000e+00
# dream.time      (INFO) | Solved interval 1.760000e+00 to 1.770000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.780000e+00
# dream.time      (INFO) | Solved interval 1.770000e+00 to 1.780000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.790000e+00
# dream.time      (INFO) | Solved interval 1.780000e+00 to 1.790000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.800000e+00
# dream.time      (INFO) | Solved interval 1.790000e+00 to 1.800000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.810000e+00
# dream.time      (INFO) | Solved interval 1.800000e+00 to 1.810000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.820000e+00
# dream.time      (INFO) | Solved interval 1.810000e+00 to 1.820000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.830000e+00
# dream.time      (INFO) | Solved interval 1.820000e+00 to 1.830000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.840000e+00
# dream.time      (INFO) | Solved interval 1.830000e+00 to 1.840000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.850000e+00
# dream.time      (INFO) | Solved interval 1.840000e+00 to 1.850000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.860000e+00
# dream.time      (INFO) | Solved interval 1.850000e+00 to 1.860000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.870000e+00
# dream.time      (INFO) | Solved interval 1.860000e+00 to 1.870000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.880000e+00
# dream.time      (INFO) | Solved interval 1.870000e+00 to 1.880000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.890000e+00
# dream.time      (INFO) | Solved interval 1.880000e+00 to 1.890000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.900000e+00
# dream.time      (INFO) | Solved interval 1.890000e+00 to 1.900000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.910000e+00
# dream.time      (INFO) | Solved interval 1.900000e+00 to 1.910000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.920000e+00
# dream.time      (INFO) | Solved interval 1.910000e+00 to 1.920000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.930000e+00
# dream.time      (INFO) | Solved interval 1.920000e+00 to 1.930000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.940000e+00
# dream.time      (INFO) | Solved interval 1.930000e+00 to 1.940000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.950000e+00
# dream.time      (INFO) | Solved interval 1.940000e+00 to 1.950000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.960000e+00
# dream.time      (INFO) | Solved interval 1.950000e+00 to 1.960000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.970000e+00
# dream.time      (INFO) | Solved interval 1.960000e+00 to 1.970000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.980000e+00
# dream.time      (INFO) | Solved interval 1.970000e+00 to 1.980000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 1.990000e+00
# dream.time      (INFO) | Solved interval 1.980000e+00 to 1.990000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.000000e+00
# dream.time      (INFO) | Solved interval 1.990000e+00 to 2.000000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.010000e+00
# dream.time      (INFO) | Solved interval 2.000000e+00 to 2.010000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.020000e+00
# dream.time      (INFO) | Solved interval 2.010000e+00 to 2.020000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.030000e+00
# dream.time      (INFO) | Solved interval 2.020000e+00 to 2.030000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.040000e+00
# dream.time      (INFO) | Solved interval 2.030000e+00 to 2.040000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.050000e+00
# dream.time      (INFO) | Solved interval 2.040000e+00 to 2.050000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.060000e+00
# dream.time      (INFO) | Solved interval 2.050000e+00 to 2.060000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.070000e+00
# dream.time      (INFO) | Solved interval 2.060000e+00 to 2.070000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.080000e+00
# dream.time      (INFO) | Solved interval 2.070000e+00 to 2.080000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.090000e+00
# dream.time      (INFO) | Solved interval 2.080000e+00 to 2.090000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.100000e+00
# dream.time      (INFO) | Solved interval 2.090000e+00 to 2.100000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.110000e+00
# dream.time      (INFO) | Solved interval 2.100000e+00 to 2.110000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.120000e+00
# dream.time      (INFO) | Solved interval 2.110000e+00 to 2.120000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.130000e+00
# dream.time      (INFO) | Solved interval 2.120000e+00 to 2.130000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.140000e+00
# dream.time      (INFO) | Solved interval 2.130000e+00 to 2.140000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.150000e+00
# dream.time      (INFO) | Solved interval 2.140000e+00 to 2.150000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.160000e+00
# dream.time      (INFO) | Solved interval 2.150000e+00 to 2.160000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.170000e+00
# dream.time      (INFO) | Solved interval 2.160000e+00 to 2.170000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.180000e+00
# dream.time      (INFO) | Solved interval 2.170000e+00 to 2.180000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.190000e+00
# dream.time      (INFO) | Solved interval 2.180000e+00 to 2.190000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.200000e+00
# dream.time      (INFO) | Solved interval 2.190000e+00 to 2.200000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.210000e+00
# dream.time      (INFO) | Solved interval 2.200000e+00 to 2.210000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.220000e+00
# dream.time      (INFO) | Solved interval 2.210000e+00 to 2.220000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.230000e+00
# dream.time      (INFO) | Solved interval 2.220000e+00 to 2.230000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.240000e+00
# dream.time      (INFO) | Solved interval 2.230000e+00 to 2.240000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.250000e+00
# dream.time      (INFO) | Solved interval 2.240000e+00 to 2.250000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.260000e+00
# dream.time      (INFO) | Solved interval 2.250000e+00 to 2.260000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.270000e+00
# dream.time      (INFO) | Solved interval 2.260000e+00 to 2.270000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.280000e+00
# dream.time      (INFO) | Solved interval 2.270000e+00 to 2.280000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.290000e+00
# dream.time      (INFO) | Solved interval 2.280000e+00 to 2.290000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.300000e+00
# dream.time      (INFO) | Solved interval 2.290000e+00 to 2.300000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.310000e+00
# dream.time      (INFO) | Solved interval 2.300000e+00 to 2.310000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.320000e+00
# dream.time      (INFO) | Solved interval 2.310000e+00 to 2.320000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.330000e+00
# dream.time      (INFO) | Solved interval 2.320000e+00 to 2.330000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.340000e+00
# dream.time      (INFO) | Solved interval 2.330000e+00 to 2.340000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.350000e+00
# dream.time      (INFO) | Solved interval 2.340000e+00 to 2.350000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.360000e+00
# dream.time      (INFO) | Solved interval 2.350000e+00 to 2.360000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.370000e+00
# dream.time      (INFO) | Solved interval 2.360000e+00 to 2.370000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.380000e+00
# dream.time      (INFO) | Solved interval 2.370000e+00 to 2.380000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.390000e+00
# dream.time      (INFO) | Solved interval 2.380000e+00 to 2.390000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.400000e+00
# dream.time      (INFO) | Solved interval 2.390000e+00 to 2.400000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.410000e+00
# dream.time      (INFO) | Solved interval 2.400000e+00 to 2.410000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.420000e+00
# dream.time      (INFO) | Solved interval 2.410000e+00 to 2.420000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.430000e+00
# dream.time      (INFO) | Solved interval 2.420000e+00 to 2.430000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.440000e+00
# dream.time      (INFO) | Solved interval 2.430000e+00 to 2.440000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.450000e+00
# dream.time      (INFO) | Solved interval 2.440000e+00 to 2.450000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.460000e+00
# dream.time      (INFO) | Solved interval 2.450000e+00 to 2.460000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.470000e+00
# dream.time      (INFO) | Solved interval 2.460000e+00 to 2.470000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.480000e+00
# dream.time      (INFO) | Solved interval 2.470000e+00 to 2.480000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.490000e+00
# dream.time      (INFO) | Solved interval 2.480000e+00 to 2.490000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.500000e+00
# dream.time      (INFO) | Solved interval 2.490000e+00 to 2.500000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.510000e+00
# dream.time      (INFO) | Solved interval 2.500000e+00 to 2.510000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.520000e+00
# dream.time      (INFO) | Solved interval 2.510000e+00 to 2.520000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.530000e+00
# dream.time      (INFO) | Solved interval 2.520000e+00 to 2.530000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.540000e+00
# dream.time      (INFO) | Solved interval 2.530000e+00 to 2.540000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.550000e+00
# dream.time      (INFO) | Solved interval 2.540000e+00 to 2.550000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.560000e+00
# dream.time      (INFO) | Solved interval 2.550000e+00 to 2.560000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.570000e+00
# dream.time      (INFO) | Solved interval 2.560000e+00 to 2.570000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.580000e+00
# dream.time      (INFO) | Solved interval 2.570000e+00 to 2.580000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.590000e+00
# dream.time      (INFO) | Solved interval 2.580000e+00 to 2.590000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.600000e+00
# dream.time      (INFO) | Solved interval 2.590000e+00 to 2.600000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.610000e+00
# dream.time      (INFO) | Solved interval 2.600000e+00 to 2.610000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.620000e+00
# dream.time      (INFO) | Solved interval 2.610000e+00 to 2.620000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.630000e+00
# dream.time      (INFO) | Solved interval 2.620000e+00 to 2.630000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.640000e+00
# dream.time      (INFO) | Solved interval 2.630000e+00 to 2.640000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.650000e+00
# dream.time      (INFO) | Solved interval 2.640000e+00 to 2.650000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.660000e+00
# dream.time      (INFO) | Solved interval 2.650000e+00 to 2.660000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.670000e+00
# dream.time      (INFO) | Solved interval 2.660000e+00 to 2.670000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.680000e+00
# dream.time      (INFO) | Solved interval 2.670000e+00 to 2.680000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.690000e+00
# dream.time      (INFO) | Solved interval 2.680000e+00 to 2.690000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.700000e+00
# dream.time      (INFO) | Solved interval 2.690000e+00 to 2.700000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.710000e+00
# dream.time      (INFO) | Solved interval 2.700000e+00 to 2.710000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.720000e+00
# dream.time      (INFO) | Solved interval 2.710000e+00 to 2.720000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.730000e+00
# dream.time      (INFO) | Solved interval 2.720000e+00 to 2.730000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.740000e+00
# dream.time      (INFO) | Solved interval 2.730000e+00 to 2.740000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.750000e+00
# dream.time      (INFO) | Solved interval 2.740000e+00 to 2.750000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.760000e+00
# dream.time      (INFO) | Solved interval 2.750000e+00 to 2.760000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.770000e+00
# dream.time      (INFO) | Solved interval 2.760000e+00 to 2.770000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.780000e+00
# dream.time      (INFO) | Solved interval 2.770000e+00 to 2.780000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.790000e+00
# dream.time      (INFO) | Solved interval 2.780000e+00 to 2.790000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.800000e+00
# dream.time      (INFO) | Solved interval 2.790000e+00 to 2.800000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.810000e+00
# dream.time      (INFO) | Solved interval 2.800000e+00 to 2.810000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.820000e+00
# dream.time      (INFO) | Solved interval 2.810000e+00 to 2.820000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.830000e+00
# dream.time      (INFO) | Solved interval 2.820000e+00 to 2.830000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.840000e+00
# dream.time      (INFO) | Solved interval 2.830000e+00 to 2.840000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.850000e+00
# dream.time      (INFO) | Solved interval 2.840000e+00 to 2.850000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.860000e+00
# dream.time      (INFO) | Solved interval 2.850000e+00 to 2.860000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.870000e+00
# dream.time      (INFO) | Solved interval 2.860000e+00 to 2.870000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.880000e+00
# dream.time      (INFO) | Solved interval 2.870000e+00 to 2.880000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.890000e+00
# dream.time      (INFO) | Solved interval 2.880000e+00 to 2.890000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.900000e+00
# dream.time      (INFO) | Solved interval 2.890000e+00 to 2.900000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.910000e+00
# dream.time      (INFO) | Solved interval 2.900000e+00 to 2.910000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.920000e+00
# dream.time      (INFO) | Solved interval 2.910000e+00 to 2.920000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.930000e+00
# dream.time      (INFO) | Solved interval 2.920000e+00 to 2.930000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.940000e+00
# dream.time      (INFO) | Solved interval 2.930000e+00 to 2.940000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.950000e+00
# dream.time      (INFO) | Solved interval 2.940000e+00 to 2.950000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.960000e+00
# dream.time      (INFO) | Solved interval 2.950000e+00 to 2.960000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.970000e+00
# dream.time      (INFO) | Solved interval 2.960000e+00 to 2.970000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.980000e+00
# dream.time      (INFO) | Solved interval 2.970000e+00 to 2.980000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 2.990000e+00
# dream.time      (INFO) | Solved interval 2.980000e+00 to 2.990000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.000000e+00
# dream.time      (INFO) | Solved interval 2.990000e+00 to 3.000000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.010000e+00
# dream.time      (INFO) | Solved interval 3.000000e+00 to 3.010000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.020000e+00
# dream.time      (INFO) | Solved interval 3.010000e+00 to 3.020000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.030000e+00
# dream.time      (INFO) | Solved interval 3.020000e+00 to 3.030000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.040000e+00
# dream.time      (INFO) | Solved interval 3.030000e+00 to 3.040000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.050000e+00
# dream.time      (INFO) | Solved interval 3.040000e+00 to 3.050000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.060000e+00
# dream.time      (INFO) | Solved interval 3.050000e+00 to 3.060000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.070000e+00
# dream.time      (INFO) | Solved interval 3.060000e+00 to 3.070000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.080000e+00
# dream.time      (INFO) | Solved interval 3.070000e+00 to 3.080000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.090000e+00
# dream.time      (INFO) | Solved interval 3.080000e+00 to 3.090000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.100000e+00
# dream.time      (INFO) | Solved interval 3.090000e+00 to 3.100000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.110000e+00
# dream.time      (INFO) | Solved interval 3.100000e+00 to 3.110000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.120000e+00
# dream.time      (INFO) | Solved interval 3.110000e+00 to 3.120000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.130000e+00
# dream.time      (INFO) | Solved interval 3.120000e+00 to 3.130000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.140000e+00
# dream.time      (INFO) | Solved interval 3.130000e+00 to 3.140000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.150000e+00
# dream.time      (INFO) | Solved interval 3.140000e+00 to 3.150000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.160000e+00
# dream.time      (INFO) | Solved interval 3.150000e+00 to 3.160000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.170000e+00
# dream.time      (INFO) | Solved interval 3.160000e+00 to 3.170000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.180000e+00
# dream.time      (INFO) | Solved interval 3.170000e+00 to 3.180000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.190000e+00
# dream.time      (INFO) | Solved interval 3.180000e+00 to 3.190000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.200000e+00
# dream.time      (INFO) | Solved interval 3.190000e+00 to 3.200000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.210000e+00
# dream.time      (INFO) | Solved interval 3.200000e+00 to 3.210000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.220000e+00
# dream.time      (INFO) | Solved interval 3.210000e+00 to 3.220000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.230000e+00
# dream.time      (INFO) | Solved interval 3.220000e+00 to 3.230000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.240000e+00
# dream.time      (INFO) | Solved interval 3.230000e+00 to 3.240000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.250000e+00
# dream.time      (INFO) | Solved interval 3.240000e+00 to 3.250000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.260000e+00
# dream.time      (INFO) | Solved interval 3.250000e+00 to 3.260000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.270000e+00
# dream.time      (INFO) | Solved interval 3.260000e+00 to 3.270000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.280000e+00
# dream.time      (INFO) | Solved interval 3.270000e+00 to 3.280000e+00
#
# dream.time      (INFO) | transient | hdg implicit_euler | t: 3.290000e+00
# ...
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.147718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.148000e+01
# dream.time      (INFO) | Solved interval 1.147000e+01 to 1.148000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.148436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.148718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.149000e+01
# dream.time      (INFO) | Solved interval 1.148000e+01 to 1.149000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.149436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.149718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.150000e+01
# dream.time      (INFO) | Solved interval 1.149000e+01 to 1.150000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.150436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.150718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.151000e+01
# dream.time      (INFO) | Solved interval 1.150000e+01 to 1.151000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.151436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.151718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.152000e+01
# dream.time      (INFO) | Solved interval 1.151000e+01 to 1.152000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.152436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.152718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.153000e+01
# dream.time      (INFO) | Solved interval 1.152000e+01 to 1.153000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.153436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.153718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.154000e+01
# dream.time      (INFO) | Solved interval 1.153000e+01 to 1.154000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.154436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.154718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.155000e+01
# dream.time      (INFO) | Solved interval 1.154000e+01 to 1.155000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.155436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.155718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.156000e+01
# dream.time      (INFO) | Solved interval 1.155000e+01 to 1.156000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.156436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.156718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.157000e+01
# dream.time      (INFO) | Solved interval 1.156000e+01 to 1.157000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.157436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.157718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.158000e+01
# dream.time      (INFO) | Solved interval 1.157000e+01 to 1.158000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.158436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.158718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.159000e+01
# dream.time      (INFO) | Solved interval 1.158000e+01 to 1.159000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.159436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.159718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.160000e+01
# dream.time      (INFO) | Solved interval 1.159000e+01 to 1.160000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.160436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.160718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.161000e+01
# dream.time      (INFO) | Solved interval 1.160000e+01 to 1.161000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.161436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.161718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.162000e+01
# dream.time      (INFO) | Solved interval 1.161000e+01 to 1.162000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.162436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.162718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.163000e+01
# dream.time      (INFO) | Solved interval 1.162000e+01 to 1.163000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.163436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.163718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.164000e+01
# dream.time      (INFO) | Solved interval 1.163000e+01 to 1.164000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.164436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.164718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.165000e+01
# dream.time      (INFO) | Solved interval 1.164000e+01 to 1.165000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.165436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.165718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.166000e+01
# dream.time      (INFO) | Solved interval 1.165000e+01 to 1.166000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.166436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.166718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.167000e+01
# dream.time      (INFO) | Solved interval 1.166000e+01 to 1.167000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.167436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.167718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.168000e+01
# dream.time      (INFO) | Solved interval 1.167000e+01 to 1.168000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.168436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.168718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.169000e+01
# dream.time      (INFO) | Solved interval 1.168000e+01 to 1.169000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.169436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.169718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.170000e+01
# dream.time      (INFO) | Solved interval 1.169000e+01 to 1.170000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.170436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.170718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.171000e+01
# dream.time      (INFO) | Solved interval 1.170000e+01 to 1.171000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.171436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.171718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.172000e+01
# dream.time      (INFO) | Solved interval 1.171000e+01 to 1.172000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.172436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.172718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.173000e+01
# dream.time      (INFO) | Solved interval 1.172000e+01 to 1.173000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.173436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.173718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.174000e+01
# dream.time      (INFO) | Solved interval 1.173000e+01 to 1.174000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.174436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.174718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.175000e+01
# dream.time      (INFO) | Solved interval 1.174000e+01 to 1.175000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.175436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.175718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.176000e+01
# dream.time      (INFO) | Solved interval 1.175000e+01 to 1.176000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.176436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.176718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.177000e+01
# dream.time      (INFO) | Solved interval 1.176000e+01 to 1.177000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.177436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.177718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.178000e+01
# dream.time      (INFO) | Solved interval 1.177000e+01 to 1.178000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.178436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.178718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.179000e+01
# dream.time      (INFO) | Solved interval 1.178000e+01 to 1.179000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.179436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.179718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.180000e+01
# dream.time      (INFO) | Solved interval 1.179000e+01 to 1.180000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.180436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.180718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.181000e+01
# dream.time      (INFO) | Solved interval 1.180000e+01 to 1.181000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.181436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.181718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.182000e+01
# dream.time      (INFO) | Solved interval 1.181000e+01 to 1.182000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.182436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.182718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.183000e+01
# dream.time      (INFO) | Solved interval 1.182000e+01 to 1.183000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.183436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.183718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.184000e+01
# dream.time      (INFO) | Solved interval 1.183000e+01 to 1.184000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.184436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.184718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.185000e+01
# dream.time      (INFO) | Solved interval 1.184000e+01 to 1.185000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.185436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.185718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.186000e+01
# dream.time      (INFO) | Solved interval 1.185000e+01 to 1.186000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.186436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.186718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.187000e+01
# dream.time      (INFO) | Solved interval 1.186000e+01 to 1.187000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.187436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.187718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.188000e+01
# dream.time      (INFO) | Solved interval 1.187000e+01 to 1.188000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.188436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.188718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.189000e+01
# dream.time      (INFO) | Solved interval 1.188000e+01 to 1.189000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.189436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.189718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.190000e+01
# dream.time      (INFO) | Solved interval 1.189000e+01 to 1.190000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.190436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.190718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.191000e+01
# dream.time      (INFO) | Solved interval 1.190000e+01 to 1.191000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.191436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.191718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.192000e+01
# dream.time      (INFO) | Solved interval 1.191000e+01 to 1.192000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.192436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.192718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.193000e+01
# dream.time      (INFO) | Solved interval 1.192000e+01 to 1.193000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.193436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.193718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.194000e+01
# dream.time      (INFO) | Solved interval 1.193000e+01 to 1.194000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.194436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.194718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.195000e+01
# dream.time      (INFO) | Solved interval 1.194000e+01 to 1.195000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.195436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.195718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.196000e+01
# dream.time      (INFO) | Solved interval 1.195000e+01 to 1.196000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.196436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.196718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.197000e+01
# dream.time      (INFO) | Solved interval 1.196000e+01 to 1.197000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.197436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.197718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.198000e+01
# dream.time      (INFO) | Solved interval 1.197000e+01 to 1.198000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.198436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.198718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.199000e+01
# dream.time      (INFO) | Solved interval 1.198000e+01 to 1.199000e+01
#
# dream.time      (INFO) | transient | dg sdirk33 | stage: 1 | t: 1.199436e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 2 | t: 1.199718e+01
# dream.time      (INFO) | transient | dg sdirk33 | stage: 3 | t: 1.200000e+01
# dream.time      (INFO) | Solved interval 1.199000e+01 to 1.200000e+01
